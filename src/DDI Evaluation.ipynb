# %%
import pandas as pd

# %%
pd.set_option('max_colwidth',5000)

# %%
dev_knn_500 = pd.read_csv('../outputs/ddi_test_prompts_random_42.5.50.perm_4.KNN_500_balancedsubset.csv')

# %%
dev_knn_500[['test_ready_prompt']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
for i, row in dev_knn_500[dev_knn_500['label'] != dev_knn_500['ddi_test_prompts_random_42.5.50.perm_4.KNN_500_balancedsubset']].iterrows():
    
    print(row['test_ready_prompt'])
    print('label')
    print('-'*100)
# Out:
# Sentence: Concomitant use of bromocriptine mesylate with other ergot alkaloids is not recommended.
# Drug 1: bromocriptine mesylate
# Drug 2: ergot alkaloids
# Interaction: advice
#
# Sentence: However, interactions may be expected, and UROXATRAL should NOT be used in combination with other alpha-blockers.
# Drug 1: UROXATRAL
# Drug 2: alpha-blockers
# Interaction: advice
#
# Sentence: Fentanyl Anesthesia: Severe hypotension has been reported during fentanyl anesthesia with concomitant use of a beta blocker and a calcium channel blocker.
# Drug 1: fentanyl
# Drug 2: beta blocker
# Interaction: effect
#
# Sentence: Population pharmacokinetic analyses revealed that MTX, NSAIDs, corticosteroids, and TNF blocking agents did not influence abatacept clearance.
# Drug 1: NSAIDs
# Drug 2: abatacept
# Interaction: none
#
# ...
